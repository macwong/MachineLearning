# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
men_train = pd.read_csv("_RawData/mens_train_file.csv")
men_test = pd.read_csv("_RawData/mens_test_file.csv")
women_train = pd.read_csv("_RawData/womens_train_file.csv")
women_test = pd.read_csv("_RawData/womens_test_file.csv")

# %%
print(men_train.shape)
print(men_test.shape)
print(women_train.shape)
print(women_test.shape)
# Out:
# (5000, 28)
# (2000, 28)
# (5000, 28)
# (1000, 28)

# %%
men_train.head()
# Out:
#    rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0      4      1        B  35.515042      -0.021725                3.474766
# 1      4      2        B  33.382640       1.114202                2.540801
# 2     23      1        B  22.316690      -0.254046                3.533166
# 3      9      1        F  36.837309       0.766694                0.586885
# 4      4      1        B  35.544208       0.116162                0.918725
#
#       depth  outside.sideline  outside.baseline  player.distance.travelled  \
# 0  6.797621             False             False                   1.467570
# 1  2.608708             False              True                   2.311931
# 2  9.435749             False             False                   3.903728
# 3  3.342180              True             False                   0.583745
# 4  5.499119             False             False                   2.333456
#
#     ...    opponent.depth  opponent.distance.from.center  same.side  \
# 0   ...           12.5628                         2.0724       True
# 1   ...           12.3544                         5.1124      False
# 2   ...           13.8620                         1.6564      False
# 3   ...           14.2596                         0.1606       True
# 4   ...           11.3658                         1.1082      False
#
#    previous.hitpoint  previous.time.to.net  server.is.impact.player    id  \
# 0                  F              0.445318                    False  5718
# 1                  B              0.432434                    False   371
# 2                  F              0.397538                     True  7948
# 3                  B              0.671984                     True  9312
# 4                  F              0.340411                    False  7667
#
#    train  outcome  gender
# 0      1       UE    mens
# 1      1       FE    mens
# 2      1       FE    mens
# 3      1       UE    mens
# 4      1        W    mens
#
# [5 rows x 28 columns]

# %%
men_train.describe()
# Out:
#              rally        serve        speed  net.clearance  \
# count  5000.000000  5000.000000  5000.000000    5000.000000
# mean      6.073800     1.419200    31.161443       0.630771
# std       3.729388     0.493478     8.160724       1.032237
# min       3.000000     1.000000     5.340688      -0.998184
# 25%       3.000000     1.000000    25.902134      -0.033606
# 50%       5.000000     1.000000    32.913270       0.428872
# 75%       7.000000     2.000000    37.050218       0.957190
# max      38.000000     2.000000    60.414369      12.815893
#
#        distance.from.sideline        depth  player.distance.travelled  \
# count             5000.000000  5000.000000                5000.000000
# mean                 1.446501     4.582527                   2.940785
# std                  1.107850     3.194891                   1.821582
# min                  0.000378     0.000282                   0.000000
# 25%                  0.535640     1.738331                   1.632093
# 50%                  1.194245     4.086093                   2.590722
# 75%                  2.150703     7.251723                   3.906332
# max                 16.343755    11.885770                  14.480546
#
#        player.impact.depth  player.impact.distance.from.center  player.depth  \
# count          5000.000000                         5000.000000   5000.000000
# mean             11.807125                            2.064879     12.248763
# std               3.104886                            1.245185      2.322730
# min               2.156000                            0.001200      1.389800
# 25%              10.845850                            1.058250     11.209550
# 50%              12.692500                            1.974300     12.674800
# 75%              13.741900                            2.925200     13.753000
# max              18.700600                            7.746200     18.745800
#
#        player.distance.from.center  previous.speed  previous.net.clearance  \
# count                  5000.000000     5000.000000             5000.000000
# mean                      1.323482       29.128159                0.804103
# std                       1.046213        7.005915                0.641029
# min                       0.000200        8.449117                0.027207
# 25%                       0.583400       23.745628                0.393600
# 50%                       1.073800       30.118756                0.652971
# 75%                       1.772350       34.464404                1.009070
# max                       9.352600       55.282098                5.774903
#
#        previous.distance.from.sideline  previous.depth  opponent.depth  \
# count                      5000.000000     5000.000000     5000.000000
# mean                          2.104965        4.318172       12.606633
# std                           1.043034        2.125320        2.356896
# min                           0.002634        0.010852        2.161200
# 25%                           1.269135        2.754327       11.978550
# 50%                           2.030780        4.153317       12.978000
# 75%                           2.926017        5.756835       13.900700
# max                           4.114361        9.996154       20.211000
#
#        opponent.distance.from.center  previous.time.to.net          id   train
# count                    5000.000000           5000.000000  5000.00000  5000.0
# mean                        2.466160              0.543950  4767.63540     1.0
# std                         1.346193              0.190789  2755.95677     0.0
# min                         0.001000              0.079005     1.00000     1.0
# 25%                         1.437350              0.418597  2377.75000     1.0
# 50%                         2.429400              0.503636  4742.50000     1.0
# 75%                         3.372600              0.627682  7183.25000     1.0
# max                        12.995000              1.651724  9531.00000     1.0

# %%
men_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 28 columns):
# rally                                 5000 non-null int64
# serve                                 5000 non-null int64
# hitpoint                              5000 non-null object
# speed                                 5000 non-null float64
# net.clearance                         5000 non-null float64
# distance.from.sideline                5000 non-null float64
# depth                                 5000 non-null float64
# outside.sideline                      5000 non-null bool
# outside.baseline                      5000 non-null bool
# player.distance.travelled             5000 non-null float64
# player.impact.depth                   5000 non-null float64
# player.impact.distance.from.center    5000 non-null float64
# player.depth                          5000 non-null float64
# player.distance.from.center           5000 non-null float64
# previous.speed                        5000 non-null float64
# previous.net.clearance                5000 non-null float64
# previous.distance.from.sideline       5000 non-null float64
# previous.depth                        5000 non-null float64
# opponent.depth                        5000 non-null float64
# opponent.distance.from.center         5000 non-null float64
# same.side                             5000 non-null bool
# previous.hitpoint                     5000 non-null object
# previous.time.to.net                  5000 non-null float64
# server.is.impact.player               5000 non-null bool
# id                                    5000 non-null int64
# train                                 5000 non-null int64
# outcome                               5000 non-null object
# gender                                5000 non-null object
# dtypes: bool(4), float64(16), int64(4), object(4)
# memory usage: 957.1+ KB

# %%
# Scale data
# Binarize data

men_analyse = pd.DataFrame(columns=["Name", "Type", "Unique", "NA"])

for col in men_train.columns:
    men_data = men_train[col]
    men_analyse = men_analyse.append({"Name": col, "Type": men_data.dtype, "Unique": men_data.nunique(), "NA": men_data.isnull().sum()}, ignore_index=True)
#     print(col)
#     print(men_train[col].max())

men_analyse.sort_index(by = "Type")
# Out:
# C:\Users\Dave\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   if sys.path[0] == '':
#                                   Name     Type Unique NA
# 23             server.is.impact.player     bool      2  0
# 20                           same.side     bool      2  0
# 7                     outside.sideline     bool      2  0
# 8                     outside.baseline     bool      2  0
# 0                                rally    int64     30  0
# 1                                serve    int64      2  0
# 25                               train    int64      1  0
# 24                                  id    int64   5000  0
# 22                previous.time.to.net  float64   5000  0
# 19       opponent.distance.from.center  float64   4505  0
# 18                      opponent.depth  float64   4605  0
# 17                      previous.depth  float64   5000  0
# 16     previous.distance.from.sideline  float64   5000  0
# 15              previous.net.clearance  float64   5000  0
# 13         player.distance.from.center  float64   4219  0
# 12                        player.depth  float64   4582  0
# 11  player.impact.distance.from.center  float64   4447  0
# 10                 player.impact.depth  float64   4686  0
# 9            player.distance.travelled  float64   4991  0
# 6                                depth  float64   5000  0
# 5               distance.from.sideline  float64   5000  0
# 4                        net.clearance  float64   4999  0
# 3                                speed  float64   5000  0
# 14                      previous.speed  float64   5000  0
# 26                             outcome   object      3  0
# 21                   previous.hitpoint   object      4  0
# 2                             hitpoint   object      4  0
# 27                              gender   object      1  0
