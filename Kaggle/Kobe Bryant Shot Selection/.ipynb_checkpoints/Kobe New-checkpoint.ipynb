# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv")
pd.set_option("display.max_columns",100)
data.head(10)
# Out:
#          action_type combined_shot_type  game_event_id   game_id      lat  \
# 0          Jump Shot          Jump Shot             10  20000012  33.9723
# 1          Jump Shot          Jump Shot             12  20000012  34.0443
# 2          Jump Shot          Jump Shot             35  20000012  33.9093
# 3          Jump Shot          Jump Shot             43  20000012  33.8693
# 4  Driving Dunk Shot               Dunk            155  20000012  34.0443
# 5          Jump Shot          Jump Shot            244  20000012  34.0553
# 6         Layup Shot              Layup            251  20000012  34.0443
# 7          Jump Shot          Jump Shot            254  20000012  34.0163
# 8          Jump Shot          Jump Shot            265  20000012  33.9363
# 9  Running Jump Shot          Jump Shot            294  20000012  33.9193
#
#    loc_x  loc_y       lon  minutes_remaining  period  playoffs   season  \
# 0    167     72 -118.1028                 10       1         0  2000-01
# ...

# %%
X_all = data[['combined_shot_type', 'shot_zone_area', 'shot_zone_basic', 'season', 'shot_distance', 'shot_made_flag']].copy()
X_all = X_all.join(pd.get_dummies(X_all["combined_shot_type"]))
X_all = X_all[np.isnan(X_all["shot_made_flag"]) == False]
X_test = data[np.isnan(data["shot_made_flag"])]
X_test = X_test.drop("shot_made_flag", axis = 1)
y = X_all["shot_made_flag"]
X = X_all.drop("shot_made_flag", axis=1)

# %%
X_all
# Out:
#       combined_shot_type         shot_zone_area        shot_zone_basic  \
# 1              Jump Shot           Left Side(L)              Mid-Range
# 2              Jump Shot   Left Side Center(LC)              Mid-Range
# 3              Jump Shot  Right Side Center(RC)              Mid-Range
# 4                   Dunk              Center(C)        Restricted Area
# 5              Jump Shot           Left Side(L)              Mid-Range
# 6                  Layup              Center(C)        Restricted Area
# 8              Jump Shot           Left Side(L)  In The Paint (Non-RA)
# 9              Jump Shot              Center(C)  In The Paint (Non-RA)
# 10             Jump Shot   Left Side Center(LC)      Above the Break 3
# 11             Jump Shot  Right Side Center(RC)              Mid-Range
# 12             Jump Shot           Left Side(L)  In The Paint (Non-RA)
# 13             Jump Shot           Left Side(L)              Mid-Range
# ...

# %%
pd.get_dummies(X["combined_shot_type"])
# Out:
#        Bank Shot  Dunk  Hook Shot  Jump Shot  Layup  Tip Shot
# 1              0     0          0          1      0         0
# 2              0     0          0          1      0         0
# 3              0     0          0          1      0         0
# 4              0     1          0          0      0         0
# 5              0     0          0          1      0         0
# 6              0     0          0          0      1         0
# 8              0     0          0          1      0         0
# 9              0     0          0          1      0         0
# 10             0     0          0          1      0         0
# 11             0     0          0          1      0         0
# 12             0     0          0          1      0         0
# 13             0     0          0          1      0         0
# 14             0     0          0          1      0         0
# 15             0     0          0          1      0         0
# ...

# %%
X_all.corr()
# Out:
#                 shot_distance  shot_made_flag
# shot_distance        1.000000       -0.198242
# shot_made_flag      -0.198242        1.000000

# %%
X.columns
# Out:
# Index(['combined_shot_type', 'shot_zone_area', 'shot_zone_basic', 'season',
#        'shot_distance'],
#       dtype='object')

# %%
# new_data = X[['combined_shot_type', 'loc_x', 'loc_y', 'shot_distance']].copy()
# 'action_type', 
# 'combined_shot_type', Y
# 'game_event_id', 
# 'game_id', 
# 'lat',
# 'loc_x', 
# 'loc_y', 
# 'lon', 
# 'minutes_remaining', 
# 'period', 
# 'playoffs',
# 'season', 
# 'seconds_remaining', 
# 'shot_distance', 
# 'shot_type',
# 'shot_zone_area', 
# 'shot_zone_basic', 
# 'shot_zone_range', 
# 'team_id',
# 'team_name', 
# 'game_date', 
# 'matchup', 
# 'opponent', 
# 'shot_id'

# %%
plt.scatter(X["loc_x"], X["loc_y"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Dave\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'loc_x'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
X
# Out:
#       combined_shot_type         shot_zone_area        shot_zone_basic  \
# 1              Jump Shot           Left Side(L)              Mid-Range
# 2              Jump Shot   Left Side Center(LC)              Mid-Range
# 3              Jump Shot  Right Side Center(RC)              Mid-Range
# 4                   Dunk              Center(C)        Restricted Area
# 5              Jump Shot           Left Side(L)              Mid-Range
# 6                  Layup              Center(C)        Restricted Area
# 8              Jump Shot           Left Side(L)  In The Paint (Non-RA)
# 9              Jump Shot              Center(C)  In The Paint (Non-RA)
# 10             Jump Shot   Left Side Center(LC)      Above the Break 3
# 11             Jump Shot  Right Side Center(RC)              Mid-Range
# 12             Jump Shot           Left Side(L)  In The Paint (Non-RA)
# 13             Jump Shot           Left Side(L)              Mid-Range
# ...

# %%
X_all["action_type"].value_counts()
X_all["combined_shot_type"].value_counts()
# Out:
# Jump Shot    19710
# Layup         4532
# Dunk          1056
# Tip Shot       152
# Hook Shot      127
# Bank Shot      120
# Name: combined_shot_type, dtype: int64

# %%
ax = sns.barplot(x="shot_made_flag", y="action_type", data=X_all)

# %%
# X["action_type"]
ax = sns.barplot(x="shot_made_flag", y="combined_shot_type", data=X_all)

# %%
ax = sns.pointplot(x="shot_distance", y="shot_made_flag", data=X_all)

# %%
ax = sns.barplot(x="shot_made_flag", y="shot_type", data=X_all)

# %%
ax = sns.barplot(x="shot_made_flag", y="shot_zone_area", data=X_all)
